# %%
import geopandas as gpd
import matplotlib.pyplot as plt
coast = gpd.read_file("ne_10m/ne_10m_coastline.shp")

# Look at the first few rows

# Look at the technical metadata
print(coast.info())
coast
coast.plot(figsize=(10, 5), color='blue', linewidth=0.5)
plt.title("World Coastline from Shapefile")
plt.show()
print(coast.crs)
print(coast.columns)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4133 entries, 0 to 4132
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   featurecla  4133 non-null   str
#  1   scalerank   4133 non-null   int64
#  2   min_zoom    4133 non-null   float64
#  3   geometry    4133 non-null   geometry
# dtypes: float64(1), geometry(1), int64(1), str(1)
# memory usage: 165.6 KB
# None
# EPSG:4326
# Index(['featurecla', 'scalerank', 'min_zoom', 'geometry'], dtype='str')

# %%
argentina_coast = coast.cx[-75:-50, -55:-20]
argentina_coast.plot()
plt.show()

# %%
ca_coast = coast.cx[-124:-114 ,32:43]
ca_coast.plot()
plt.show()

# %%
ca_coast.reset_index()


# lines = ca_coast['geometry'].iloc[0].coords
# print(list(lines))
# line = ca_coast['geometry'].iloc[0].length
# line
# Out:
#              index  scalerank  min_zoom
# count     9.000000   9.000000  9.000000
# mean   1383.333333   4.666667  4.000000
# std    1381.574283   1.802776  1.732051
# min     251.000000   0.000000  0.000000
# 25%     764.000000   5.000000  4.000000
# 50%     767.000000   5.000000  4.000000
# 75%     769.000000   5.000000  4.000000
# max    3806.000000   6.000000  6.000000
